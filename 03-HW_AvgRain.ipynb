# %%
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Load in csv
rain_df = pd.read_csv("Resources/avg_rain_state.csv")
rain_df.head()
# Out:
#         State  Inches  Milli­metres  Rank
# 0     Alabama    58.3          1480     4
# 1      Alaska    22.5           572    39
# 2     Arizona    13.6           345    47
# 3    Arkansas    50.6          1284     8
# 4  California    22.2           563    40

# %%
# Set x axis and tick locations
x_axis = np.arange(len(rain_df))
tick_locations = [value+0.4 for value in x_axis]

# %%
# Create a list indicating where to write x labels and set figure size to adjust for space
plt.figure(figsize=(20,3))
plt.bar(x_axis, rain_df["Inches"], color='r', alpha=0.5, align="edge")
plt.xticks(tick_locations, rain_df["State"], rotation="vertical")
# Out:
# <img src="data:image/png;base64,..." width="2000">
# ([<matplotlib.axis.XTick at 0x11d33c0f0>,
#   <matplotlib.axis.XTick at 0x11d0c69e8>,
#   <matplotlib.axis.XTick at 0x11d0c65f8>,
#   <matplotlib.axis.XTick at 0x11d3e0b38>,
#   <matplotlib.axis.XTick at 0x11d3f70b8>,
#   <matplotlib.axis.XTick at 0x11d3f75c0>,
#   <matplotlib.axis.XTick at 0x11d3f7b38>,
#   <matplotlib.axis.XTick at 0x11d3fc160>,
#   <matplotlib.axis.XTick at 0x11d3fc668>,
#   <matplotlib.axis.XTick at 0x11d3f7588>,
#   <matplotlib.axis.XTick at 0x11d3fcbe0>,
#   <matplotlib.axis.XTick at 0x11d3fcef0>,
#   <matplotlib.axis.XTick at 0x11d4034a8>,
#   <matplotlib.axis.XTick at 0x11d403a20>,
#   <matplotlib.axis.XTick at 0x11d403e80>,
#   <matplotlib.axis.XTick at 0x11d40a550>,
#   <matplotlib.axis.XTick at 0x11d40aac8>,
#   <matplotlib.axis.XTick at 0x11d4100f0>,
#   <matplotlib.axis.XTick at 0x11d4105f8>,
#   <matplotlib.axis.XTick at 0x11d40ae48>,
#   <matplotlib.axis.XTick at 0x11d403ac8>,
#   <matplotlib.axis.XTick at 0x11d410470>,
#   <matplotlib.axis.XTick at 0x11d4170b8>,
#   <matplotlib.axis.XTick at 0x11d4175c0>,
#   <matplotlib.axis.XTick at 0x11d417b38>,
#   <matplotlib.axis.XTick at 0x11d41e160>,
#   <matplotlib.axis.XTick at 0x11d41e668>,
#   <matplotlib.axis.XTick at 0x11d41ebe0>,
#   <matplotlib.axis.XTick at 0x11d425198>,
#   <matplotlib.axis.XTick at 0x11d41ea58>,
#   <matplotlib.axis.XTick at 0x11d4032b0>,
#   <matplotlib.axis.XTick at 0x11d3fc0b8>,
#   <matplotlib.axis.XTick at 0x11d425908>,
#   <matplotlib.axis.XTick at 0x11d425e80>,
#   <matplotlib.axis.XTick at 0x11d42b438>,
#   <matplotlib.axis.XTick at 0x11d42b9b0>,
#   <matplotlib.axis.XTick at 0x11d42bf28>,
#   <matplotlib.axis.XTick at 0x11d4334e0>,
#   <matplotlib.axis.XTick at 0x11d42b4e0>,
#   <matplotlib.axis.XTick at 0x11d4258d0>,
#   <matplotlib.axis.XTick at 0x11d433828>,
#   <matplotlib.axis.XTick at 0x11d433f60>,
#   <matplotlib.axis.XTick at 0x11d43b518>,
#   <matplotlib.axis.XTick at 0x11d43ba90>,
#   <matplotlib.axis.XTick at 0x11d4420b8>,
#   <matplotlib.axis.XTick at 0x11d4425c0>,
#   <matplotlib.axis.XTick at 0x11d442b38>,
#   <matplotlib.axis.XTick at 0x11d44a160>,
#   <matplotlib.axis.XTick at 0x11d442f28>,
#   <matplotlib.axis.XTick at 0x11d43b5f8>],
#  <a list of 50 Text xticklabel objects>)

# %%
# Set x and y limits
plt.xlim(-0.25, len(x_axis))
plt.ylim(0, max(rain_df["Inches"])+10)
# Out:
# (0, 73.7)

# %%
# Set a Title and labels
plt.title("Average Rain per State")
plt.xlabel("State")
plt.ylabel("Average Amount of Rainfall in Inches")
# Out:
# Text(433.94444444444446, 0.5, 'Average Amount of Rainfall in Inches')

# %%
# Save our graph and show the grap
plt.tight_layout()
plt.savefig("Images/avg_state_rain.png")
plt.show()
